# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/user/ashish/ml/big mart/big_mart.csv')

# %%
print(df.shape)
df.head()
# Out:
# (8523, 12)
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   str
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   str
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   str
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   str
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   str
#  9   Outlet_Location_Type       8523 non-null   str
#  10  Outlet_Type                8523 non-null   str
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), str(7)
# memory usage: 799.2 KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Item_Weight'].mean()
# Out:
# np.float64(12.857645184135977)

# %%
df['Item_Weight']=df['Item_Weight'].fillna(df['Item_Weight'].mean())

# %%
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: str

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna(list(df['Outlet_Size'].mode())[0])

# %% [markdown]
# mx=int(df['Item_Outlet_Sales'].max())
# mn=int(df['Item_Outlet_Sales'].min())

# %% [markdown]
# df.loc[df['Item_Outlet_Sales'].isna(), 'Item_Outlet_Sales'] = [
#     random.randrange(mn, mx)
#     for i in range(df['Item_Outlet_Sales'].isna().sum())
# ]

# %% [markdown]
# df['Item_Outlet_Sales']

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat','low fat':'Low Fat','reg':'Regular'})

# %%
df.to_csv('big_mart.csv',index=False)
